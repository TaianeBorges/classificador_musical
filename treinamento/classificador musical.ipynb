# %%
import pandas as pd

# %%
df = pd.read_csv('beyonce_rihanna.csv', index_col=0)
df.head()
# Out:
#                                  Nome da Música  \
# 0                            '03 Bonnie & Clyde
# 1  ***Flawless (Feat. Chimamanda Ngozi Adichie)
# 2               ***Flawless (Feat. Nicki Minaj)
# 3                                           1+1
# 4                     6 Inch (Feat. The Weeknd)
#
#                                                 link  \
# 0                      /beyonce/03-bonnie-clyde.html
# 1  /beyonce/flawless-feat-chimamanda-ngozi-adichi...
# 2            /beyonce/flawless-feat-nicki-minaj.html
# 3                                   /beyonce/11.html
# 4               /beyonce/6-inch-feat-the-weeknd.html
#
#                                                album  \
# 0  I Am... Yours: An Intimate Performance at Wynn...
# 1                                            BEYONCÉ
# 2                         BEYONCÉ [Platinum Edition]
# 3                         BEYONCÉ [Platinum Edition]
# 4                                           LEMONADE
#
#                                                letra  artista
# 0  Jay-z Uh-uh-uh You ready b? Let's go get 'em. ...  Beyoncé
# 1  Your challengers are a young group from Housto...  Beyoncé
# 2  Dum-da-de-da Do, do, do, do, do, do (Coming do...  Beyoncé
# 3  If I ain't got nothing I got you If I ain't go...  Beyoncé
# 4  Six inch heels She walked in the club like nob...  Beyoncé

# %%
exemplo = df['letra'][10]
exemplo
# Out:
# "Here I am Looking in the mirror An open face, the pain erased Now the sky is clearer I can see the sun Now that all is, all is said and done, oh  There you are Always strong when I need you You let me give And now I live, fearless and protected With the one I will love After all is, all is said and done  I once believed that hearts were made to bleed (Inside I once believed that hearts were made to bleed, oh baby) But now I'm not afraid to say I need you, I need you so stay with me  These precious (precious) hours (yeah) Greet each dawn in open arms And dream, into tomorrow  Where there's only love After all is, all is said and done  (Yeah baby) Oh baby (Inside I once believed, That hearts were meant to bleed)  (I'll never) I'll never be afraid to say I need you, I need you, so here  Here we are in the still of this moment Fear is gone, hope lives on  We found our happy ending For there's only love (only love) And this sweet, sweet love After all is, all is said and done  Yeah baby after all is (all is)  All is said and done"

# %%
#tranformando palavras de um texto em tokens.
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Taiane
# [nltk_data]     Borges\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
tokens = word_tokenize(exemplo)
tokens
# Out:
# ['Here',
#  'I',
#  'am',
#  'Looking',
#  'in',
#  'the',
#  'mirror',
#  'An',
#  'open',
#  'face',
#  ',',
#  'the',
#  'pain',
#  'erased',
#  'Now',
#  'the',
#  'sky',
#  'is',
#  'clearer',
#  'I',
#  'can',
#  'see',
#  'the',
#  'sun',
#  'Now',
#  'that',
#  'all',
#  'is',
#  ',',
#  'all',
#  'is',
#  'said',
#  'and',
#  'done',
#  ',',
#  'oh',
#  'There',
#  'you',
#  'are',
#  'Always',
#  'strong',
#  'when',
#  'I',
#  'need',
#  'you',
#  'You',
#  'let',
#  'me',
#  'give',
#  'And',
#  'now',
#  'I',
#  'live',
#  ',',
#  'fearless',
#  'and',
#  'protected',
#  'With',
#  'the',
#  'one',
#  'I',
#  'will',
#  'love',
#  'After',
#  'all',
#  'is',
#  ',',
#  'all',
#  'is',
#  'said',
#  'and',
#  'done',
#  'I',
#  'once',
#  'believed',
#  'that',
#  'hearts',
#  'were',
#  'made',
#  'to',
#  'bleed',
#  '(',
#  'Inside',
#  'I',
#  'once',
#  'believed',
#  'that',
#  'hearts',
#  'were',
#  'made',
#  'to',
#  'bleed',
#  ',',
#  'oh',
#  'baby',
#  ')',
#  'But',
#  'now',
#  'I',
#  "'m",
#  'not',
#  'afraid',
#  'to',
#  'say',
#  'I',
#  'need',
#  'you',
#  ',',
#  'I',
#  'need',
#  'you',
#  'so',
#  'stay',
#  'with',
#  'me',
#  'These',
#  'precious',
#  '(',
#  'precious',
#  ')',
#  'hours',
#  '(',
#  'yeah',
#  ')',
#  'Greet',
#  'each',
#  'dawn',
#  'in',
#  'open',
#  'arms',
#  'And',
#  'dream',
#  ',',
#  'into',
#  'tomorrow',
#  'Where',
#  'there',
#  "'s",
#  'only',
#  'love',
#  'After',
#  'all',
#  'is',
#  ',',
#  'all',
#  'is',
#  'said',
#  'and',
#  'done',
#  '(',
#  'Yeah',
#  'baby',
#  ')',
#  'Oh',
#  'baby',
#  '(',
#  'Inside',
#  'I',
#  'once',
#  'believed',
#  ',',
#  'That',
#  'hearts',
#  'were',
#  'meant',
#  'to',
#  'bleed',
#  ')',
#  '(',
#  'I',
#  "'ll",
#  'never',
#  ')',
#  'I',
#  "'ll",
#  'never',
#  'be',
#  'afraid',
#  'to',
#  'say',
#  'I',
#  'need',
#  'you',
#  ',',
#  'I',
#  'need',
#  'you',
#  ',',
#  'so',
#  'here',
#  'Here',
#  'we',
#  'are',
#  'in',
#  'the',
#  'still',
#  'of',
#  'this',
#  'moment',
#  'Fear',
#  'is',
#  'gone',
#  ',',
#  'hope',
#  'lives',
#  'on',
#  'We',
#  'found',
#  'our',
#  'happy',
#  'ending',
#  'For',
#  'there',
#  "'s",
#  'only',
#  'love',
#  '(',
#  'only',
#  'love',
#  ')',
#  'And',
#  'this',
#  'sweet',
#  ',',
#  'sweet',
#  'love',
#  'After',
#  'all',
#  'is',
#  ',',
#  'all',
#  'is',
#  'said',
#  'and',
#  'done',
#  'Yeah',
#  'baby',
#  'after',
#  'all',
#  'is',
#  '(',
#  'all',
#  'is',
#  ')',
#  'All',
#  'is',
#  'said',
#  'and',
#  'done']

# %%
import re
letras = re.findall(r'\b[A-zÀ-úü]+\b', exemplo.lower())
letras
# Out:
# ['here',
#  'i',
#  'am',
#  'looking',
#  'in',
#  'the',
#  'mirror',
#  'an',
#  'open',
#  'face',
#  'the',
#  'pain',
#  'erased',
#  'now',
#  'the',
#  'sky',
#  'is',
#  'clearer',
#  'i',
#  'can',
#  'see',
#  'the',
#  'sun',
#  'now',
#  'that',
#  'all',
#  'is',
#  'all',
#  'is',
#  'said',
#  'and',
#  'done',
#  'oh',
#  'there',
#  'you',
#  'are',
#  'always',
#  'strong',
#  'when',
#  'i',
#  'need',
#  'you',
#  'you',
#  'let',
#  'me',
#  'give',
#  'and',
#  'now',
#  'i',
#  'live',
#  'fearless',
#  'and',
#  'protected',
#  'with',
#  'the',
#  'one',
#  'i',
#  'will',
#  'love',
#  'after',
#  'all',
#  'is',
#  'all',
#  'is',
#  'said',
#  'and',
#  'done',
#  'i',
#  'once',
#  'believed',
#  'that',
#  'hearts',
#  'were',
#  'made',
#  'to',
#  'bleed',
#  'inside',
#  'i',
#  'once',
#  'believed',
#  'that',
#  'hearts',
#  'were',
#  'made',
#  'to',
#  'bleed',
#  'oh',
#  'baby',
#  'but',
#  'now',
#  'i',
#  'm',
#  'not',
#  'afraid',
#  'to',
#  'say',
#  'i',
#  'need',
#  'you',
#  'i',
#  'need',
#  'you',
#  'so',
#  'stay',
#  'with',
#  'me',
#  'these',
#  'precious',
#  'precious',
#  'hours',
#  'yeah',
#  'greet',
#  'each',
#  'dawn',
#  'in',
#  'open',
#  'arms',
#  'and',
#  'dream',
#  'into',
#  'tomorrow',
#  'where',
#  'there',
#  's',
#  'only',
#  'love',
#  'after',
#  'all',
#  'is',
#  'all',
#  'is',
#  'said',
#  'and',
#  'done',
#  'yeah',
#  'baby',
#  'oh',
#  'baby',
#  'inside',
#  'i',
#  'once',
#  'believed',
#  'that',
#  'hearts',
#  'were',
#  'meant',
#  'to',
#  'bleed',
#  'i',
#  'll',
#  'never',
#  'i',
#  'll',
#  'never',
#  'be',
#  'afraid',
#  'to',
#  'say',
#  'i',
#  'need',
#  'you',
#  'i',
#  'need',
#  'you',
#  'so',
#  'here',
#  'here',
#  'we',
#  'are',
#  'in',
#  'the',
#  'still',
#  'of',
#  'this',
#  'moment',
#  'fear',
#  'is',
#  'gone',
#  'hope',
#  'lives',
#  'on',
#  'we',
#  'found',
#  'our',
#  'happy',
#  'ending',
#  'for',
#  'there',
#  's',
#  'only',
#  'love',
#  'only',
#  'love',
#  'and',
#  'this',
#  'sweet',
#  'sweet',
#  'love',
#  'after',
#  'all',
#  'is',
#  'all',
#  'is',
#  'said',
#  'and',
#  'done',
#  'yeah',
#  'baby',
#  'after',
#  'all',
#  'is',
#  'all',
#  'is',
#  'all',
#  'is',
#  'said',
#  'and',
#  'done']

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Taiane
# [nltk_data]     Borges\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#eliminando as stopwords(palavras não relevantes para a maquina, exp: artigos e preposições)
#utilizandoa lista de stopwords disponivel na biblioteca NLTK.
from nltk.corpus import stopwords
stops = stopwords.words('english')
stops
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
#ELIMINANDO 
sem_stopwords = [palavra for palavra in letras if palavra not in stops]
palavras_importantes = " ".join(sem_stopwords)
palavras_importantes
# Out:
# 'looking mirror open face pain erased sky clearer see sun said done oh always strong need let give live fearless protected one love said done believed hearts made bleed inside believed hearts made bleed oh baby afraid say need need stay precious precious hours yeah greet dawn open arms dream tomorrow love said done yeah baby oh baby inside believed hearts meant bleed never never afraid say need need still moment fear gone hope lives found happy ending love love sweet sweet love said done yeah baby said done'

# %%
#LEMATIZAÇÃO - ferramenta para transformar verbos conjugados, elas reduzem todas as formas verbais conjugadas á sua raiz

import spacy
spc = spacy.load('en_core_web_sm')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-27-ba739d7f385f> in <module>
#       1 #LEMATIZAÇÃO - ferramenta para transformar verbos conjugados, elas reduzem todas as formas verbais conjugadas á sua raiz
#       2
# ----> 3 import spacy
#       4 spc = spacy.load('en_core_web_sm')
#
# ModuleNotFoundError: No module named 'spacy'

# %%
palavras_importantes.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-1edb3a1229cd> in <module>
# ----> 1 palavras_importantes.head()
#
# NameError: name 'palavras_importantes' is not defined

# %%
import spc
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-30-8b8cf955d62d> in <module>
# ----> 1 import spc
#
# ModuleNotFoundError: No module named 'spc'

# %%
def limpar_texto(texto):

    # selecionando apenas as letras e convertendo para minúscula 
    letras =  re.findall(r'\b[A-zÀ-úü]+\b', texto.lower())
    
    # removendo as stopwords 
    stops = set(stopwords.words('portuguese'))
    palavras = [w for w in letras if w not in stops]
    palavras_importantes = " ".join(palavras)
    
    # lematização 
    spc_letras = spc(palavras_importantes)
    lemmas = [token.lemma_ if token.pos_ == 'VERB' else str(token) for token in spc_letras]
    texto_limpo = " ".join(lemmas)
    
    return texto_limpo

# %%
texto_limpo = df

# %%
df.head()
# Out:
#                                  Nome da Música  \
# 0                            '03 Bonnie & Clyde
# 1  ***Flawless (Feat. Chimamanda Ngozi Adichie)
# 2               ***Flawless (Feat. Nicki Minaj)
# 3                                           1+1
# 4                     6 Inch (Feat. The Weeknd)
#
#                                                 link  \
# 0                      /beyonce/03-bonnie-clyde.html
# 1  /beyonce/flawless-feat-chimamanda-ngozi-adichi...
# 2            /beyonce/flawless-feat-nicki-minaj.html
# 3                                   /beyonce/11.html
# 4               /beyonce/6-inch-feat-the-weeknd.html
#
#                                                album  \
# 0  I Am... Yours: An Intimate Performance at Wynn...
# 1                                            BEYONCÉ
# 2                         BEYONCÉ [Platinum Edition]
# 3                         BEYONCÉ [Platinum Edition]
# 4                                           LEMONADE
#
#                                                letra  artista
# 0  Jay-z Uh-uh-uh You ready b? Let's go get 'em. ...  Beyoncé
# 1  Your challengers are a young group from Housto...  Beyoncé
# 2  Dum-da-de-da Do, do, do, do, do, do (Coming do...  Beyoncé
# 3  If I ain't got nothing I got you If I ain't go...  Beyoncé
# 4  Six inch heels She walked in the club like nob...  Beyoncé

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
#Bags of words
count_vect = CountVectorizer()
X = count_vect.fit_transform(df['Texto Limpo'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda-3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Texto Limpo'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-78b9f84cf7bb> in <module>
#       1 #Bags of words
#       2 count_vect = CountVectorizer()
# ----> 3 X = count_vect.fit_transform(df['Texto Limpo'])
#
# ~\Anaconda-3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~\Anaconda-3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Texto Limpo'

# %%
count_vect = sklearn.feature_extraction.text.CountVectorizer(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-1230adc0f0c6> in <module>
# ----> 1 count_vect = sklearn.feature_extraction.text.CountVectorizer(df)
#
# NameError: name 'sklearn' is not defined

# %%
count_vect.get_feature_names()
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-51-14f53663e672> in <module>
# ----> 1 count_vect.get_feature_names()
#
# ~\Anaconda-3\lib\site-packages\sklearn\feature_extraction\text.py in get_feature_names(self)
#    1150             self._validate_vocabulary()
#    1151
# -> 1152         self._check_vocabulary()
#    1153
#    1154         return [t for t, i in sorted(self.vocabulary_.items(),
#
# ~\Anaconda-3\lib\site-packages\sklearn\feature_extraction\text.py in _check_vocabulary(self)
#     387         """Check if vocabulary is empty or missing (not fit-ed)"""
#     388         msg = "%(name)s - Vocabulary wasn't fitted."
# --> 389         check_is_fitted(self, 'vocabulary_', msg=msg),
#     390
#     391         if len(self.vocabulary_) == 0:
#
# ~\Anaconda-3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     912
#     913     if not all_or_any([hasattr(estimator, attr) for attr in attributes]):
# --> 914         raise NotFittedError(msg % {'name': type(estimator).__name__})
#     915
#     916
#
# NotFittedError: CountVectorizer - Vocabulary wasn't fitted.

# %% [raw]
# count_vect.vocabulary_.get('love')

# %%
df_cv = pd.DataFrame(X.toarray(), columns = count_vect.get_feature_names())
df_cv.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-8ca60a3fd950> in <module>
# ----> 1 df_cv = pd.DataFrame(X.toarray(), columns = count_vectorizer.get_feature_names())
#       2 df_cv.head()
#
# NameError: name 'X' is not defined

# %%
df_cv.iloc[:, 10:20]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-f427ea6fe707> in <module>
# ----> 1 df_cv.iloc[:, 10:20]
#
# NameError: name 'df_cv' is not defined

# %%
#separando Treino e Teste
from sklearn.model_selection import train_test_split

X = X.toarray()
y = df['artista']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-eac69a73d46b> in <module>
#       2 from sklearn.model_selection import train_test_split
#       3
# ----> 4 X = X.toarray()
#       5 y = df['artista']
#       6
#
# NameError: name 'X' is not defined

# %%
from sklearn.naive_bayes import MultinomialNB

#Criando o Modelo Naive Bayes 
naive_bayes = MultinomialNB()

#.......Treinando o Modelo.......
naive_bayes.fit(X_train, y_train)

#Fazendo as previsões
naive_bayes_pred = naive_bayes.predict(X_test)
